# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/kato/Desktop/mypython/成績一覧表.csv")
df
# Out:
#         試験名    担任  学年  組   №      氏名  国語  数学  理科  社会  英語   合計
# 0   1学期中間試験  山田　諭   3  1   1   浅野　麻耶  84  74  65  77  78  378
# 1   1学期中間試験  山田　諭   3  1   2   井戸　弘樹  55  75  45  58  98  331
# 2   1学期中間試験  山田　諭   3  1   3    岡　和重  84  55  75  48  44  306
# 3   1学期中間試験  山田　諭   3  1   4    岡本　昭  75  68  75  54  65  337
# 4   1学期中間試験  山田　諭   3  1   5   小川　雅行  68  64  85  65  58  340
# 5   1学期中間試験  山田　諭   3  1   6    斉藤　敦  57  85  65  85  87  379
# 6   1学期中間試験  山田　諭   3  1   7   佐野　俊一  95  75  54  77  54  355
# 7   1学期中間試験  山田　諭   3  1   8    白浜　誠  84  45  68  68  88  353
# 8   1学期中間試験  山田　諭   3  1   9   田中　賢治  75  68  75  54  65  337
# 9   1学期中間試験  山田　諭   3  1  10   中村　晴彦  84  58  95  85  87  409
# 10  1学期中間試験  山田　諭   3  1  11    原　文雄  66  75  77  95  95  408
# 11  1学期中間試験  山田　諭   3  1  12   光中　弘樹  54  77  58  44  65  298
# 12  1学期中間試験  山田　諭   3  1  13   安原　大輔  75  84  45  58  88  350
# 13  1学期中間試験  山田　諭   3  1  14    柵原　鉄  95  91  86  57  77  406
# ...

# %%
hu=df.at["1学期中間試験","国語"]
hu
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 hu=df.at["1学期中間試験","国語"]
#       2 hu
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/core/indexing.py:2431, in _AtIndexer.__getitem__(self, key)
#    2428         raise ValueError("Invalid call for scalar access (getting)!")
#    2429     return self.obj.loc[key]
# -> 2431 return super().__getitem__(key)
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/core/indexing.py:2382, in _ScalarAccessIndexer.__getitem__(self, key)
#    2379         raise ValueError("Invalid call for scalar access (getting)!")
#    2381 key = self._convert_key(key)
# -> 2382 return self.obj._get_value(*key, takeable=self._takeable)
#
# ...

# %%
y = hu == 55

# %%
y
# Out:
# True
