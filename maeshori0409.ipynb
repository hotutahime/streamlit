# %%
import pandas as pd
import numpy as np

# %%
#変数「reserve_tb」の中にcsvを読み込む
reserve_tb = pd.read_csv("/Users/kato/Desktop/mypython/awesomebook-master/data/reserve.csv" , encoding="UTF-8")

# %%
#reserve_tbの全データ
reserve_tb
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date
# 0            r1     h_75         c_1  2016-03-06 13:09:42   2016-03-26  \
# 1            r2    h_219         c_1  2016-07-16 23:39:55   2016-07-20
# 2            r3    h_179         c_1  2016-09-24 10:03:17   2016-10-19
# 3            r4    h_214         c_1  2017-03-08 03:20:10   2017-03-29
# 4            r5     h_16         c_1  2017-09-05 19:50:37   2017-09-22
# ...         ...      ...         ...                  ...          ...
# 4025      r4026    h_129       c_999  2017-06-27 23:00:02   2017-07-10
# 4026      r4027     h_97       c_999  2017-09-29 05:24:57   2017-10-09
# 4027      r4028     h_27       c_999  2018-03-14 05:01:45   2018-04-02
# 4028      r4029     h_48      c_1000  2016-04-16 15:20:17   2016-05-10
# 4029      r4030    h_117      c_1000  2016-06-06 08:16:51   2016-07-06
#
#      checkin_time checkout_date  people_num  total_price
# 0        10:00:00    2016-03-29           4        97200
# ...

# %%
#変数[[""]]とする事で必要な「列」を抽出出来る
reserve_tb[["reserve_id", "hotel_id", "customer_id",
            "reserve_datetime","checkin_date", "checkin_time",
            "checkout_date"]]
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date
# 0            r1     h_75         c_1  2016-03-06 13:09:42   2016-03-26  \
# 1            r2    h_219         c_1  2016-07-16 23:39:55   2016-07-20
# 2            r3    h_179         c_1  2016-09-24 10:03:17   2016-10-19
# 3            r4    h_214         c_1  2017-03-08 03:20:10   2017-03-29
# 4            r5     h_16         c_1  2017-09-05 19:50:37   2017-09-22
# ...         ...      ...         ...                  ...          ...
# 4025      r4026    h_129       c_999  2017-06-27 23:00:02   2017-07-10
# 4026      r4027     h_97       c_999  2017-09-29 05:24:57   2017-10-09
# 4027      r4028     h_27       c_999  2018-03-14 05:01:45   2018-04-02
# 4028      r4029     h_48      c_1000  2016-04-16 15:20:17   2016-05-10
# 4029      r4030    h_117      c_1000  2016-06-06 08:16:51   2016-07-06
#
#      checkin_time checkout_date
# 0        10:00:00    2016-03-29
# 1        11:30:00    2016-07-21
# ...

# %%
reserve_tb
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date
# 0            r1     h_75         c_1  2016-03-06 13:09:42   2016-03-26  \
# 1            r2    h_219         c_1  2016-07-16 23:39:55   2016-07-20
# 2            r3    h_179         c_1  2016-09-24 10:03:17   2016-10-19
# 3            r4    h_214         c_1  2017-03-08 03:20:10   2017-03-29
# 4            r5     h_16         c_1  2017-09-05 19:50:37   2017-09-22
# ...         ...      ...         ...                  ...          ...
# 4025      r4026    h_129       c_999  2017-06-27 23:00:02   2017-07-10
# 4026      r4027     h_97       c_999  2017-09-29 05:24:57   2017-10-09
# 4027      r4028     h_27       c_999  2018-03-14 05:01:45   2018-04-02
# 4028      r4029     h_48      c_1000  2016-04-16 15:20:17   2016-05-10
# 4029      r4030    h_117      c_1000  2016-06-06 08:16:51   2016-07-06
#
#      checkin_time checkout_date  people_num  total_price
# 0        10:00:00    2016-03-29           4        97200
# ...

# %%
#queryは指定の条件でデータを抜き出せる
reserve_tb.query('customer_id == "c_1"')
# Out:
#   reserve_id hotel_id customer_id     reserve_datetime checkin_date
# 0         r1     h_75         c_1  2016-03-06 13:09:42   2016-03-26  \
# 1         r2    h_219         c_1  2016-07-16 23:39:55   2016-07-20
# 2         r3    h_179         c_1  2016-09-24 10:03:17   2016-10-19
# 3         r4    h_214         c_1  2017-03-08 03:20:10   2017-03-29
# 4         r5     h_16         c_1  2017-09-05 19:50:37   2017-09-22
# 5         r6    h_241         c_1  2017-11-27 18:47:05   2017-12-04
# 6         r7    h_256         c_1  2017-12-29 10:38:36   2018-01-25
# 7         r8    h_241         c_1  2018-05-26 08:42:51   2018-06-08
#
#   checkin_time checkout_date  people_num  total_price
# 0     10:00:00    2016-03-29           4        97200
# 1     11:30:00    2016-07-21           2        20600
# 2     09:00:00    2016-10-22           2        33600
# 3     11:00:00    2017-03-30           4       194400
# 4     10:30:00    2017-09-23           3        68100
# ...

# %%
#DF名＋クエリモジュールで一行で条件を指定する。＆、｜を使用することができる。
reserve_tb.query('"2016-10-13" <= checkout_date <= "2016-10-14"')
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date
# 284        r285    h_121        c_67  2016-09-27 06:13:19   2016-10-12  \
# 513        r514     h_74       c_120  2016-10-06 03:12:04   2016-10-11
# 1065      r1066    h_205       c_261  2016-09-14 02:57:59   2016-10-11
# 1480      r1481    h_116       c_364  2016-09-17 17:45:39   2016-10-11
# 1546      r1547    h_149       c_377  2016-09-27 08:19:24   2016-10-10
# 1709      r1710     h_59       c_422  2016-09-19 04:17:25   2016-10-10
# 1932      r1933    h_113       c_477  2016-09-24 09:04:26   2016-10-12
# 2058      r2059      h_9       c_517  2016-09-19 15:32:35   2016-10-11
# 2115      r2116     h_77       c_527  2016-10-05 00:44:09   2016-10-11
# 2170      r2171    h_177       c_540  2016-09-28 01:21:26   2016-10-11
# 2203      r2204     h_82       c_549  2016-09-27 01:47:57   2016-10-10
# 2290      r2291    h_230       c_574  2016-10-09 04:34:14   2016-10-12
# ...

# %%
#DF名＋クエリモジュールで一行で条件を指定する。＆、｜を使用することができる。
reserve_tb.query('checkout_date == "2016-10-13" | checkout_date == "2016-10-14"')
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date
# 284        r285    h_121        c_67  2016-09-27 06:13:19   2016-10-12  \
# 0        10:00:00    2016-03-29           4        97200
# ...

# %%
result = reserve_tb \
    .groupby("hotel_id") \
    .agg({"reserve_id": "count" , "customer_id": "nunique"})
result
# Out:
#           reserve_id  customer_id
# hotel_id
# h_1               10           10
# h_10               3            3
# h_100             20           19
# h_101             17           17
# h_102             13           13
# ...              ...          ...
# h_95              13           13
# h_96              13           13
# h_97              16           16
# h_98              17           16
# h_99              14           14
#
# [300 rows x 2 columns]

# %%
result.reset_index(inplace=True)
result.columns = ["hotel_id", "rsv_cnt", "cus_cnt"]
result.columns
# Out:
# Index(['hotel_id', 'rsv_cnt', 'cus_cnt'], dtype='object')

# %%
result = reserve_tb \
    .groupby(["hotel_id","people_num"])["total_price"]\
    .sum().reset_index()
result
# Out:
#      hotel_id  people_num  total_price
# 0         h_1           1       156600
# 1         h_1           2       156600
# 2         h_1           3       391500
# 3         h_1           4       417600
# 4        h_10           1        11200
# ...       ...         ...          ...
# 1154     h_98           3       793800
# 1155     h_98           4       453600
# 1156     h_99           1       179200
# 1157     h_99           2       448000
# 1158     h_99           4      1164800
#
# [1159 rows x 3 columns]

# %%
result.rename(columns={"total_price":"price_sum"},inplace=True)
result
# Out:
#      hotel_id  people_num  price_sum
# 0         h_1           1     156600
# 1         h_1           2     156600
# 2         h_1           3     391500
# 3         h_1           4     417600
# 4        h_10           1      11200
# ...       ...         ...        ...
# 1154     h_98           3     793800
# 1155     h_98           4     453600
# 1156     h_99           1     179200
# 1157     h_99           2     448000
# 1158     h_99           4    1164800
#
# [1159 rows x 3 columns]

# %%
result = reserve_tb \
    .groupby("hotel_id") \
    .agg({"total_price": ["max","min","mean", "median",
                          lambda x: np.percentile(x, q=20)]}) \
    .reset_index()
result.columns = ["hotel_id" , "price_max", "price_min" , "price_mean" ,
                  "price_median" , "price_20per"]

result
# Out:
#     hotel_id  price_max  price_min     price_mean  price_median  price_20per
# 0        h_1     208800      26100  112230.000000      104400.0      73080.0
# 1       h_10      67200      11200   42933.333333       50400.0      26880.0
# 2      h_100      57600       4800   27600.000000       28800.0       9600.0
# 3      h_101     168000      14000   75764.705882       56000.0      30800.0
# 4      h_102      72000      12000   32769.230769       24000.0      18000.0
# ..       ...        ...        ...            ...           ...          ...
# 295     h_95     518400      43200  275815.384615      259200.0     146880.0
# 296     h_96      66600       7400   33015.384615       29600.0      17760.0
# 297     h_97     250800      20900   83600.000000       62700.0      20900.0
# 298     h_98     226800      18900   96723.529412       75600.0      56700.0
# 299     h_99     268800      44800  128000.000000       89600.0      67200.0
#
# [300 rows x 6 columns]

# %%
pd.merge(reserve_tb, hotel_tb, on="hotel_id", how="inner").query('people_num == 1 & is_business')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 pd.merge(reserve_tb, hotel_tb, on="hotel_id", how="inner").query('people_num == 1 & is_business')
#
# NameError: name 'hotel_tb' is not defined
