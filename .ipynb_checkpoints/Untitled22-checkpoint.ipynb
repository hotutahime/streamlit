# %%
import PySimpleGUI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import PySimpleGUI
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/PySimpleGUI/__init__.py:2
#       1 name = "PySimpleGUI"
# ----> 2 from .PySimpleGUI import *
#       3 from .PySimpleGUI import __version__
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/PySimpleGUI/PySimpleGUI.py:136
#      39 """
#      40     Copyright 2018, 2019, 2020, 2021, 2022 PySimpleGUI(tm)
#      41
#    (...)
#     132     "Thank you" has fueled this project. I'm incredibly grateful to have users that are in turn grateful. It's a feedback loop of gratitude. What a fantastic thing!
#     133 """
#     135 # all of the tkinter involved imports
# --> 136 import tkinter as tk
#     137 from tkinter import filedialog
#     138 from tkinter.colorchooser import askcolor
#
# ...
