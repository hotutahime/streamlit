# %%
import requests
from bs4 import BeautifulSoup
import urllib
import pandas as pd

# %%
url = "https://travel.rakuten.co.jp/yado/aomori/aomori.html?lid=jparea_undated_map"

# %%
html = requests.get(url)
html.encoding = html.apparent_encoding
soup = BeautifulSoup(html.content , "html.parser")

# %%
hotel_price = []

for htlprice in soup.find_all(class_="htlPrice"):
    htlpricetext = htlprice.text
    hotel_price.append(htlpricetext)

# %%
hotel_names = []

for element in soup.find_all("h1"):
    text = element.text.replace("こちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績がある等の独自の条件を満たしたプリファードプログラム参加施設です。楽天トラベルへサービス利用料を支払うことにより、原則同条件の他の施設よりも上位に表示されています。（ヘルプページ参照）", "")
    hotel_names.append(text)

# %%
df = pd.DataFrame({"ホテル名": hotel_names})
print(df)
# Out:
#                                                  ホテル名
# 0                          \n青森・浅虫温泉 ホテル・旅館\n\t\t\t\t
# 1   ホテルＪＡＬシティ青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 2   ダイワロイネットホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多...
# 3   スーパーホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊...
# 4   ホテルサンルート青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿...
# 5   アートホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実...
# 6   ホテルルートイン青森中央インター\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もし...
# 7   まちなか温泉　青森センターホテル\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もし...
# 8   ホテルマイステイズ青森駅前\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多...
# 9   ホテルルートイン青森駅前\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多く...
# 10  浅虫温泉　南部屋・海扇閣（なんぶや・かいせんかく）\nこちらの宿泊施設は、宿泊者からの総合評...
# 11  アルファホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊...
# 12  リッチモンドホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 13  スマイルホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊...
# 14  浅虫温泉　辰巳館\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実...
# 15  アパホテル〈青森駅県庁通〉\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多...
# 16  ホテルＪＡＬシティ青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 17  東横ＩＮＮ新青森駅東口\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 18  ホテル２１３５\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績...
# 19  ホテルパサージュＩＩ\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿...
# 20  割烹旅館　さつき\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実...
# 21  東横ＩＮＮ青森駅前\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊...
# 22  アパホテル〈青森駅東〉\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 23  浅虫温泉　椿館\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績...
# 24  浅虫温泉　津軽藩本陣の宿　旅館柳の湯\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、...
# 25  ホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績があ...
# 26  浅虫温泉　絶景の宿　浅虫さくら観光ホテル\nこちらの宿泊施設は、宿泊者からの総合評価点数が高...
# 27  浅虫温泉　ホテル秋田屋\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 28  ホテルセレクトイン青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 29  浅虫温泉　宿屋つばき\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿...
# 30  ウィークリー翔　ホテルチトセ\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは...
# 31  アップルパレス青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊...

# %%
df = df.drop(df.index[0])
df
# Out:
#                                                  ホテル名
# 2   ダイワロイネットホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多...
# 3   スーパーホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊...
# 4   ホテルサンルート青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿...
# 5   アートホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実...
# 6   ホテルルートイン青森中央インター\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もし...
# 7   まちなか温泉　青森センターホテル\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もし...
# 8   ホテルマイステイズ青森駅前\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多...
# 9   ホテルルートイン青森駅前\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多く...
# 10  浅虫温泉　南部屋・海扇閣（なんぶや・かいせんかく）\nこちらの宿泊施設は、宿泊者からの総合評...
# 11  アルファホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊...
# 12  リッチモンドホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 13  スマイルホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊...
# 14  浅虫温泉　辰巳館\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実...
# 15  アパホテル〈青森駅県庁通〉\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多...
# 16  ホテルＪＡＬシティ青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 17  東横ＩＮＮ新青森駅東口\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 18  ホテル２１３５\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績...
# 19  ホテルパサージュＩＩ\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿...
# 20  割烹旅館　さつき\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実...
# 21  東横ＩＮＮ青森駅前\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊...
# 22  アパホテル〈青森駅東〉\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 23  浅虫温泉　椿館\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績...
# 24  浅虫温泉　津軽藩本陣の宿　旅館柳の湯\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、...
# 25  ホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績があ...
# 26  浅虫温泉　絶景の宿　浅虫さくら観光ホテル\nこちらの宿泊施設は、宿泊者からの総合評価点数が高...
# 27  浅虫温泉　ホテル秋田屋\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 28  ホテルセレクトイン青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 29  浅虫温泉　宿屋つばき\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿...
# 30  ウィークリー翔　ホテルチトセ\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは...
# 31  アップルパレス青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊...

# %%
df2 = pd.DataFrame({"価格": hotel_price})
print(df2)
# Out:
#                                                 価格
# 0     \n    \t\t[最安料金]\n\t\t\t3,410円〜（消費税込3,750円〜）
# 1     \n    \t\t[最安料金]\n\t\t\t5,364円〜（消費税込5,900円〜）
# 2     \n    \t\t[最安料金]\n\t\t\t2,846円〜（消費税込3,130円〜）
# 3     \n    \t\t[最安料金]\n\t\t\t2,728円〜（消費税込3,000円〜）
# 4     \n    \t\t[最安料金]\n\t\t\t2,946円〜（消費税込3,240円〜）
# 5     \n    \t\t[最安料金]\n\t\t\t5,091円〜（消費税込5,600円〜）
# 6     \n    \t\t[最安料金]\n\t\t\t4,091円〜（消費税込4,500円〜）
# 7     \n    \t\t[最安料金]\n\t\t\t3,028円〜（消費税込3,330円〜）
# 8     \n    \t\t[最安料金]\n\t\t\t4,637円〜（消費税込5,100円〜）
# 9   \n    \t\t[最安料金]\n\t\t\t12,000円〜（消費税込13,200円〜）
# 10    \n    \t\t[最安料金]\n\t\t\t2,728円〜（消費税込3,000円〜）
# 11    \n    \t\t[最安料金]\n\t\t\t4,681円〜（消費税込5,149円〜）
# 12    \n    \t\t[最安料金]\n\t\t\t2,273円〜（消費税込2,500円〜）
# 13  \n    \t\t[最安料金]\n\t\t\t10,000円〜（消費税込11,000円〜）
# 14    \n    \t\t[最安料金]\n\t\t\t3,546円〜（消費税込3,900円〜）
# 15    \n    \t\t[最安料金]\n\t\t\t3,410円〜（消費税込3,750円〜）
# 16    \n    \t\t[最安料金]\n\t\t\t3,682円〜（消費税込4,050円〜）
# 17    \n    \t\t[最安料金]\n\t\t\t3,828円〜（消費税込4,210円〜）
# 18    \n    \t\t[最安料金]\n\t\t\t3,000円〜（消費税込3,300円〜）
# 19  \n    \t\t[最安料金]\n\t\t\t18,182円〜（消費税込20,000円〜）
# 20    \n    \t\t[最安料金]\n\t\t\t3,682円〜（消費税込4,050円〜）
# 21    \n    \t\t[最安料金]\n\t\t\t3,000円〜（消費税込3,300円〜）
# 22    \n    \t\t[最安料金]\n\t\t\t8,000円〜（消費税込8,800円〜）
# 23    \n    \t\t[最安料金]\n\t\t\t7,000円〜（消費税込7,700円〜）
# 24    \n    \t\t[最安料金]\n\t\t\t5,400円〜（消費税込5,940円〜）
# 25  \n    \t\t[最安料金]\n\t\t\t10,000円〜（消費税込11,000円〜）
# 26    \n    \t\t[最安料金]\n\t\t\t6,000円〜（消費税込6,600円〜）
# 27    \n    \t\t[最安料金]\n\t\t\t2,519円〜（消費税込2,770円〜）
# 28    \n    \t\t[最安料金]\n\t\t\t4,319円〜（消費税込4,750円〜）
# 29    \n    \t\t[最安料金]\n\t\t\t1,910円〜（消費税込2,100円〜）
# 30    \n    \t\t[最安料金]\n\t\t\t5,637円〜（消費税込6,200円〜）

# %%
df3 = pd.concat([df, df2], axis=1)
df3
# Out:
#                                                  ホテル名
# 2   ダイワロイネットホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多...  \
# 3   スーパーホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊...
# 4   ホテルサンルート青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿...
# 5   アートホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実...
# 6   ホテルルートイン青森中央インター\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もし...
# 7   まちなか温泉　青森センターホテル\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もし...
# 8   ホテルマイステイズ青森駅前\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多...
# 9   ホテルルートイン青森駅前\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多く...
# 10  浅虫温泉　南部屋・海扇閣（なんぶや・かいせんかく）\nこちらの宿泊施設は、宿泊者からの総合評...
# 11  アルファホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊...
# 12  リッチモンドホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 13  スマイルホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊...
# 14  浅虫温泉　辰巳館\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実...
# 15  アパホテル〈青森駅県庁通〉\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多...
# 16  ホテルＪＡＬシティ青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 17  東横ＩＮＮ新青森駅東口\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 18  ホテル２１３５\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績...
# 19  ホテルパサージュＩＩ\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿...
# 20  割烹旅館　さつき\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実...
# 21  東横ＩＮＮ青森駅前\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊...
# 22  アパホテル〈青森駅東〉\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 23  浅虫温泉　椿館\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績...
# 24  浅虫温泉　津軽藩本陣の宿　旅館柳の湯\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、...
# 25  ホテル青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊実績があ...
# 26  浅虫温泉　絶景の宿　浅虫さくら観光ホテル\nこちらの宿泊施設は、宿泊者からの総合評価点数が高...
# 27  浅虫温泉　ホテル秋田屋\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 28  ホテルセレクトイン青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの...
# 29  浅虫温泉　宿屋つばき\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿...
# 30  ウィークリー翔　ホテルチトセ\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは...
# 31  アップルパレス青森\nこちらの宿泊施設は、宿泊者からの総合評価点数が高い、もしくは多くの宿泊...
# 0                                                 NaN
# 1                                                 NaN
#
#                                                 価格
# 2     \n    \t\t[最安料金]\n\t\t\t2,846円〜（消費税込3,130円〜）
# 3     \n    \t\t[最安料金]\n\t\t\t2,728円〜（消費税込3,000円〜）
# 4     \n    \t\t[最安料金]\n\t\t\t2,946円〜（消費税込3,240円〜）
# 5     \n    \t\t[最安料金]\n\t\t\t5,091円〜（消費税込5,600円〜）
# 6     \n    \t\t[最安料金]\n\t\t\t4,091円〜（消費税込4,500円〜）
# 7     \n    \t\t[最安料金]\n\t\t\t3,028円〜（消費税込3,330円〜）
# 8     \n    \t\t[最安料金]\n\t\t\t4,637円〜（消費税込5,100円〜）
# 9   \n    \t\t[最安料金]\n\t\t\t12,000円〜（消費税込13,200円〜）
# 10    \n    \t\t[最安料金]\n\t\t\t2,728円〜（消費税込3,000円〜）
# 11    \n    \t\t[最安料金]\n\t\t\t4,681円〜（消費税込5,149円〜）
# 12    \n    \t\t[最安料金]\n\t\t\t2,273円〜（消費税込2,500円〜）
# 13  \n    \t\t[最安料金]\n\t\t\t10,000円〜（消費税込11,000円〜）
# 14    \n    \t\t[最安料金]\n\t\t\t3,546円〜（消費税込3,900円〜）
# 15    \n    \t\t[最安料金]\n\t\t\t3,410円〜（消費税込3,750円〜）
# 16    \n    \t\t[最安料金]\n\t\t\t3,682円〜（消費税込4,050円〜）
# 17    \n    \t\t[最安料金]\n\t\t\t3,828円〜（消費税込4,210円〜）
# 18    \n    \t\t[最安料金]\n\t\t\t3,000円〜（消費税込3,300円〜）
# 19  \n    \t\t[最安料金]\n\t\t\t18,182円〜（消費税込20,000円〜）
# 20    \n    \t\t[最安料金]\n\t\t\t3,682円〜（消費税込4,050円〜）
# 21    \n    \t\t[最安料金]\n\t\t\t3,000円〜（消費税込3,300円〜）
# 22    \n    \t\t[最安料金]\n\t\t\t8,000円〜（消費税込8,800円〜）
# 23    \n    \t\t[最安料金]\n\t\t\t7,000円〜（消費税込7,700円〜）
# 24    \n    \t\t[最安料金]\n\t\t\t5,400円〜（消費税込5,940円〜）
# 25  \n    \t\t[最安料金]\n\t\t\t10,000円〜（消費税込11,000円〜）
# 26    \n    \t\t[最安料金]\n\t\t\t6,000円〜（消費税込6,600円〜）
# 27    \n    \t\t[最安料金]\n\t\t\t2,519円〜（消費税込2,770円〜）
# 28    \n    \t\t[最安料金]\n\t\t\t4,319円〜（消費税込4,750円〜）
# 29    \n    \t\t[最安料金]\n\t\t\t1,910円〜（消費税込2,100円〜）
# 30    \n    \t\t[最安料金]\n\t\t\t5,637円〜（消費税込6,200円〜）
# 31                                             NaN
# 0     \n    \t\t[最安料金]\n\t\t\t3,410円〜（消費税込3,750円〜）
# 1     \n    \t\t[最安料金]\n\t\t\t5,364円〜（消費税込5,900円〜）
