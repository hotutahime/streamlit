# %%
import cv2
img = cv2.imread("/Users/kato/Downloads/uchidenokoduchi_eto08_hitsuji.png")

cv2.startWindowThread()
cv2.imshow("image" , img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(0)
# Out:
# 13

# %%
import cv2
img = cv2.imread("/Users/kato/Downloads/uchidenokoduchi_eto08_hitsuji.png")
img = cv2.flip(img, 1)

cv2.startWindowThread()
cv2.imshow("image" , img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(0)
# Out:
# 3

# %%
import cv2
img = cv2.imread("/Users/kato/Downloads/uchidenokoduchi_eto08_hitsuji.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2.startWindowThread()
cv2.imshow("image" , img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(0)
# Out:
# 3

# %%
import cv2
img = cv2.imread("/Users/kato/Downloads/uchidenokoduchi_eto08_hitsuji.png")

size = 224
img = cv2.resize(img, (size , size))

cv2.startWindowThread()
cv2.imshow("image" , img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(0)
# Out:
# 3

# %%
import cv2
img = cv2.imread("/Users/kato/Downloads/money_creditcard_cut.png")

cv2.startWindowThread()
cv2.imshow("image" , img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(0)
# Out:
# 3

# %%
import cv2

img1 = cv2.imread("/Users/kato/Downloads/uchidenokoduchi_eto08_hitsuji.png")
img2 = cv2.imread("/Users/kato/Downloads/money_creditcard_cut.png")

img2 = cv2.resize(img2 , img1.shape[1::-1])

img = cv2.addWeighted(img1 , 0.5 , img2 , 0.5 , 0)

cv2.startWindowThread()
cv2.imshow("image" , img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(0)
# Out:
# 3

# %%
import cv2

def Face_Cut(img):
    cascade_file = "haarcascade_frontalfae_alt_xml"
    cascade = cv2.CascadeClassifier(cascade_file)
    
    gray = cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)
    
    face_list = cascade.detectMultiScale(gray,
                                         scaleFactor=1.11,
                                         minNeighbors=5,
                                         minSize=(128,128),
                                         flags = cv2.CASCADE_SCALE_IMAGE)
    
    
    color = (0,0,255)
    
    if len(face_list) > 0:
        x,y,w,h = face
        cv2.rectangle(img,(x,y),(x+w,y+h),color,thickness=2)
    
    return img

# %%
cap = cv2.VideoCapture(0)

while True:
    ret , frame = cap.read()
    img = Face_Cut(frame)
    cv2.startWindowThread()
    cv2.imshow("Frame" , img)
    k = cv2.waitKey(1)
    if k == 27:
        break

cap.release()
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(0)
# Out:
# [ERROR:0@326.812] global persistence.cpp:505 open Can't open file: 'haarcascade_frontalfae_alt_xml' in read mode
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[11], line 5
#       3 while True:
#       4     ret , frame = cap.read()
# ----> 5     img = Face_Cut(frame)
#       6     cv2.startWindowThread()
#       7     cv2.imshow("Frame" , img)
#
# Cell In[10], line 9, in Face_Cut(img)
#       5 cascade = cv2.CascadeClassifier(cascade_file)
#       7 gray = cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)
# ----> 9 face_list = cascade.detectMultiScale(gray,
#      10                                      scaleFactor=1.11,
#      11                                      minNeighbors=5,
#      12                                      minSize=(128,128),
#      13                                      flags = cv2.CASCADE_SCALE_IMAGE)
#      16 color = (0,0,255)
#      18 if len(face_list) > 0:
#
# error: OpenCV(4.7.0) /Users/xperience/GHA-OCV-Python/_work/opencv-python/opencv-python/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'
