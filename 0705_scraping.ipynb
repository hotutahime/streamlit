# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://news.yahoo.co.jp/"

# %%
res = requests.get(url)

# %%
res.text
# Out:
# '<!DOCTYPE html><html lang="ja"><head><title>Yahoo!ニュース</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/><meta name="viewport" content="width=1010"/><meta http-equiv="Content-Style-Type" content="text/css"/><meta http-equiv="Content-Script-Type" content="text/javascript"/><meta name="description" content="Yahoo!ニュースは、新聞・通信社が配信するニュースのほか、映像、雑誌や個人の書き手が執筆する記事など多種多様なニュースを掲載しています。"/><meta name="robots" content="noarchive, max-image-preview:large"/><meta name="format-detection" content="telephone=no"/><meta name="google-site-verification" content="dVyTbsDzUrUAjCE1aCH9hKwZ8sOsCsvi2uhuBvasrp8"/><meta property="og:site_name" content="Yahoo!ニュース"/><meta property="og:image" content="https://s.yimg.jp/images/news-web/all/images/ogp_default.png"/><meta property="og:description" content="Yahoo!ニュースは、新聞・通信社が配信するニュースのほか、映像、雑誌や個人の書き手が執筆する記事など多種多様なニュースを掲載しています。"/><meta property="og:title" content="Yahoo!ニュース"/><meta property="og:type" content="website"/><meta property="og:url"
# ...

# %%
soup_top = BeautifulSoup(res.text, "html.parser")

# %%
soup_top
# Out:
# <!DOCTYPE html>
# ...

# %%
soup_top_news = soup_top.select("#uamods-topics > div > div > div > ul")
print(soup_top_news[0].prettify())
# Out:
# <ul>
#  <li class="sc-fHCHyC jhKFuK" data-ual="service:news;opttype:pc;apptype:web;element_id:first-main-topics-text;id_type:shannon_article;content_id:0b5a450275d3e15c6ce7a2c26aa1d01f5344c3bd;mtestid:mfn_36765=art08t2&amp;mfn_18800=ttlg1t2;" data-ual-view-type="list">
#   <a class="sc-dtLLSn dpehyt" data-cl-params="_cl_vmodule:tpc_maj;_cl_link:title;_cl_position:1;" data-ual-gotocontent="true" href="https://news.yahoo.co.jp/pickup/6468514">
#    日本医師会「第9波になっている」
#   </a>
#  </li>
#  <li class="sc-fHCHyC jhKFuK" data-ual="service:news;opttype:pc;apptype:web;element_id:first-main-topics-text;id_type:shannon_article;content_id:b4e23a3be659479aaa71f59295efe9e1d912336e;mtestid:mfn_36765=art08t2&amp;mfn_18800=ttlg1t2;" data-ual-view-type="list">
#   <a class="sc-dtLLSn dpehyt" data-cl-params="_cl_vmodule:tpc_maj;_cl_link:title;_cl_position:2;" data-ual-gotocontent="true" href="https://news.yahoo.co.jp/pickup/6468519">
#    九州7日から大雨恐れ 6日に対策を
#   </a>
#  </li>
# ...

# %%
top_news_list = soup_top_news[0].find_all("a")
print(top_news_list)
# Out:
# [<a class="sc-dtLLSn dpehyt" data-cl-params="_cl_vmodule:tpc_maj;_cl_link:title;_cl_position:1;" data-ual-gotocontent="true" href="https://news.yahoo.co.jp/pickup/6468514">日本医師会「第9波になっている」</a>, <a class="sc-dtLLSn dpehyt" data-cl-params="_cl_vmodule:tpc_maj;_cl_link:title;_cl_position:2;" data-ual-gotocontent="true" href="https://news.yahoo.co.jp/pickup/6468519">九州7日から大雨恐れ 6日に対策を</a>, <a class="sc-dtLLSn dpehyt" data-cl-params="_cl_vmodule:tpc_maj;_cl_link:title;_cl_position:3;" data-ual-gotocontent="true" href="https://news.yahoo.co.jp/pickup/6468521">SBI 台湾大手と半導体工場建設へ<span class="sc-WZYut jLeSfx"><span aria-label="NEW" class="sc-eirqVv XiyIJ" role="img" type="NEW"></span></span></a>, <a class="sc-dtLLSn dpehyt" data-cl-params="_cl_vmodule:tpc_maj;_cl_link:title;_cl_position:4;" data-ual-gotocontent="true" href="https://news.yahoo.co.jp/pickup/6468520">遊びで海に飛び込む 高校生が死亡<span class="sc-WZYut jLeSfx"><span aria-label="NEW" class="sc-eirqVv XiyIJ" role="img" type="NEW"></span></span></a
# ...

# %%
for news in top_news_list:
    print(news.text)
    print(news["href"], end="\n\n")
# Out:
# 日本医師会「第9波になっている」
# https://news.yahoo.co.jp/pickup/6468514
#
# 九州7日から大雨恐れ 6日に対策を
# https://news.yahoo.co.jp/pickup/6468519
#
# SBI 台湾大手と半導体工場建設へ
# https://news.yahoo.co.jp/pickup/6468521
#
# 遊びで海に飛び込む 高校生が死亡
# https://news.yahoo.co.jp/pickup/6468520
#
# 横田基地でPFAS漏出 米軍認める
# https://news.yahoo.co.jp/pickup/6468525
#
# 鳥羽氏 調理専門校の学部長を退任
# https://news.yahoo.co.jp/pickup/6468522
#
# 大谷 球宴で登板「厳しくなった」
# https://news.yahoo.co.jp/pickup/6468472
#
# 山田裕貴の交際 事務所否定せず
# https://news.yahoo.co.jp/pickup/6468509

# %%
top_ul = []

for i in top_news_list:
    top_ul.append(i["href"])

# %%
top_ul
# Out:
# ['https://news.yahoo.co.jp/pickup/6468514',
#  'https://news.yahoo.co.jp/pickup/6468519',
#  'https://news.yahoo.co.jp/pickup/6468521',
#  'https://news.yahoo.co.jp/pickup/6468520',
#  'https://news.yahoo.co.jp/pickup/6468525',
#  'https://news.yahoo.co.jp/pickup/6468522',
#  'https://news.yahoo.co.jp/pickup/6468472',
#  'https://news.yahoo.co.jp/pickup/6468509']

# %%
for url_all in top_ul:

# %%
url_2 = "https://news.yahoo.co.jp/pickup/6468514"
res2 = requests.get(url_2)
res2.text
#uamods-pickup > div.sc-hGsYiN.hkzxwK > div > p > a
# Out:
# '<!DOCTYPE html><html lang="ja"><head><title>日本医師会「第9波になっている」 - Yahoo!ニュース</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/><meta name="viewport" content="width=1010"/><meta http-equiv="Content-Style-Type" content="text/css"/><meta http-equiv="Content-Script-Type" content="text/javascript"/><meta name="description" content="\u3000日本医師会の釜萢敏常任理事は5日の記者会見で、新型コロナウイルスの感染が沖縄県など九州地方で拡大している状況に懸念を示し「現状は第9波になっていると判断することが妥当だ」と述べた。厚生労働省は夏に"/><meta name="robots" content="noarchive, max-image-preview:large"/><meta name="format-detection" content="telephone=no"/><meta name="google-site-verification" content="dVyTbsDzUrUAjCE1aCH9hKwZ8sOsCsvi2uhuBvasrp8"/><meta property="og:site_name" content="Yahoo!ニュース"/><meta property="og:image" content="https://news-pctr.c.yimg.jp/t/news-topics/images/tpc/2023/7/5/48c57e4e8f1e3c18fbf59f24b7313500f823f7242eab8f1382197ed9a33ebade.jpg"/><meta property="og:description" content="\u3000日本医師会の釜萢敏常任理事は5日の記者会見で、新型コロナウイルスの感染が沖縄県など九州地方で拡大している状況に懸念を示
# ...

# %%
soup2 = BeautifulSoup(res2.text, "html.parser")

# %%
soup2_all = soup2.select("#uamods-pickup > div.sc-hGsYiN.hkzxwK > div > p > a")
soup2_all
# Out:
# [<a class="sc-tQTSe dfvmtn" data-cl-params="_cl_vmodule:tpc_main;_cl_link:headline;_cl_position:2;" data-ual-gotocontent="true" href="https://news.yahoo.co.jp/articles/0b5a450275d3e15c6ce7a2c26aa1d01f5344c3bd">記事全文を読む</a>]

# %%
soup2_all[0]["href"]
# Out:
# 'https://news.yahoo.co.jp/articles/0b5a450275d3e15c6ce7a2c26aa1d01f5344c3bd'
