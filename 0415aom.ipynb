# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("/Users/kato/Desktop/mypython/4-1_address_5year-old_r4_4-.xlsx")
df.reset_index()
df.head(5)
# Out:
#    Unnamed: 0 令和4年4月1日 住所別年齢別人口世帯数集計表（日本人）       Unnamed: 2 Unnamed: 3
# 0         NaN                          NaN              NaN        NaN  \
# 1         NaN                        住所コード               住所       年齢範囲
# 2         NaN                          NaN              NaN        0～4
# 3         NaN                         3010  浪打１丁目　　　　　　　　　　         15
# 4         NaN                         3020  浪打２丁目　　　　　　　　　　         20
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...
# 0        NaN        NaN        NaN        NaN        NaN        NaN  ...  \
# 1        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 2        5～9      10～14      15～19      20～24      25～29      30～34  ...
# 3         16         32         28         23         17         21  ...
# 4         26         17         25         14         19         27  ...
#
#   Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24
# ...

# %%
df2 = df.drop(df.index[[0 , 1]] , axis=0)
df2.head(5)
# Out:
#    Unnamed: 0 令和4年4月1日 住所別年齢別人口世帯数集計表（日本人）       Unnamed: 2 Unnamed: 3
# 2         NaN                          NaN              NaN        0～4  \
# 3         NaN                         3010  浪打１丁目　　　　　　　　　　         15
# 4         NaN                         3020  浪打２丁目　　　　　　　　　　         20
# 5         NaN                         5010  港町１丁目　　　　　　　　　　         24
# 6         NaN                         5020  港町２丁目　　　　　　　　　　         25
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...
# 2        5～9      10～14      15～19      20～24      25～29      30～34  ...  \
# 3         16         32         28         23         17         21  ...
# 4         26         17         25         14         19         27  ...
# 5         16         18         17         15         19         27  ...
# 6         26         30         24         40         34         30  ...
#
#   Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24
# ...

# %%
df3 = df2.drop(df2.columns[[0 , 1]] , axis=1)
df3
# Out:
#           Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 2                NaN        0～4        5～9      10～14      15～19      20～24  \
# 3    浪打１丁目　　　　　　　　　　         15         16         32         28         23
# 4    浪打２丁目　　　　　　　　　　         20         26         17         25         14
# 5    港町１丁目　　　　　　　　　　         24         16         18         17         15
# 6    港町２丁目　　　　　　　　　　         25         26         30         24         40
# ..               ...        ...        ...        ...        ...        ...
# 560              NaN        NaN        NaN        NaN        NaN        NaN
# 561              NaN        NaN        NaN        NaN        NaN        NaN
# 562              NaN        NaN        NaN        NaN        NaN        NaN
# 563              NaN        NaN        NaN        NaN        NaN        NaN
# 564              NaN       7936       9725      10959      11607      10504
#
# ...

# %%
df.drop(df.columns[0], axis=1)
# Out:
#                 令和4年4月1日 住所別年齢別人口世帯数集計表（日本人） Unnamed: 3 Unnamed: 4 Unnamed: 5
# NaN                                      NaN        NaN        NaN        NaN  \
# 住所                                     住所コード       年齢範囲        NaN        NaN
# NaN                                      NaN        0～4        5～9      10～14
# 浪打１丁目　　　　　　　　　　                         3010         15         16         32
# 浪打２丁目　　　　　　　　　　                         3020         20         26         17
# ...                                      ...        ...        ...        ...
# NaN                                      NaN        NaN        NaN        NaN
# NaN                                      NaN        NaN        NaN        NaN
# NaN                                      NaN        NaN        NaN        NaN
# NaN                                      NaN        NaN        NaN        NaN
# NaN                                      NaN       7936       9725      10959
#
# ...
