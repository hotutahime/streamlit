# %%
import pandas as pd
import numpy as np

import statsmodels.api as sm
import statsmodels.formula.api as smf

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_score = pd.read_csv("/Users/kato/Downloads/9-1_Sample.csv" , index_col="名前")
df_score
# Out:
#     性別  国語  算数  英語  理科  社会
# 名前
# A   男性  89  65  85  70  88
# B   男性  89  98  92  83  66
# C   男性  52  45  67  67  67
# D   男性  45  96  50  80  67
# E   男性  77  48  67  60  64
# F   女性  60  73  83  60  53
# G   男性  44  46  61  56  65
# H   女性  81  65  90  45  70
# I   女性  63  70  82  63  56
# J   男性  44  96  56  89  71
# K   女性  89  55  82  92  84
# L   女性  31  37  76  45  50
# M   男性  65  58  62  50  53
# N   男性  71  98  81  91  99
# O   男性  53  62  41  57  55
# P   女性  67  83  69  57  44
# Q   男性  45  56  30  73  49
# R   男性  93  87  56  90  64
# S   女性  42  57  56  33  61
# T   男性  76  90  66  67  89

# %%
df_score["性別"] = pd.get_dummies(df_score["性別"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df_score["性別"] = pd.get_dummies(df_score["性別"])
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/frame.py:3949, in DataFrame.__setitem__(self, key, value)
#    3947     self._setitem_array(key, value)
#    3948 elif isinstance(value, DataFrame):
# -> 3949     self._set_item_frame_value(key, value)
#    3950 elif (
#    3951     is_list_like(value)
#    3952     and not self.columns.is_unique
#    3953     and 1 < len(self.columns.get_indexer_for([key])) == len(value)
#    3954 ):
#    3955     # Column to set is duplicated
#    3956     self._setitem_array([key], value)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/frame.py:4078, in DataFrame._set_item_frame_value(self, key, value)
#    4076 len_cols = 1 if is_scalar(cols) or isinstance(cols, tuple) else len(cols)
#    4077 if len_cols != len(value.columns):
# -> 4078     raise ValueError("Columns must be same length as key")
#    4080 # align right-hand-side columns if self.columns
#    4081 # is multi-index and self[key] is a sub-frame
#    4082 if isinstance(self.columns, MultiIndex) and isinstance(
#    4083     loc, (slice, Series, np.ndarray, Index)
#    4084 ):
#
# ValueError: Columns must be same length as key

# %%
df_corr = df_score2.corr()
df_corr
# Out:
#           国語        算数        英語        理科        社会
# 国語  1.000000  0.320452  0.527235  0.402017  0.465048
# 算数  0.320452  1.000000  0.094329  0.589234  0.344563
# 英語  0.527235  0.094329  1.000000  0.022948  0.356136
# 理科  0.402017  0.589234  0.022948  1.000000  0.509317
# 社会  0.465048  0.344563  0.356136  0.509317  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import japanize_matplotlib

# %%
sns.heatmap(df_corr , cmap='Blues')
# Out:
# <Axes: >

# %%
sns.set_context("talk")
sns.heatmap(df_corr , cmap='Blues' , annot=True , fmt=".2f" , square=True)
# Out:
# <Axes: >
