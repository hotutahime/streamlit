# %%
import sklearn.datasets
import matplotlib.pyplot as pit

# %%
digits = sklearn.datasets.load_digits()

# %%
print("データの個数=" , len(digits.images))
print("画像データ=" , digits.images[0])
print("なんの数字か=" , digits.target[0])
# Out:
# データの個数= 1797
# 画像データ= [[ 0.  0.  5. 13.  9.  1.  0.  0.]
#  [ 0.  0. 13. 15. 10. 15.  5.  0.]
#  [ 0.  3. 15.  2.  0. 11.  8.  0.]
#  [ 0.  4. 12.  0.  0.  8.  8.  0.]
#  [ 0.  5.  8.  0.  0.  9.  8.  0.]
#  [ 0.  4. 11.  0.  1. 12.  7.  0.]
#  [ 0.  2. 14.  5. 10. 12.  0.  0.]
#  [ 0.  0.  6. 13. 10.  0.  0.  0.]]
# なんの数字か= 0

# %%
pit.imshow(digits.images[0] , cmap="Greys")
pit.show()

# %%
for i in range(50):
    pit.subplot(5, 10, i + 1)
    pit.axis("off")
    pit.title(digits.target[i])
    pit.imshow(digits.images[i], cmap="Greys")
pit.show()

# %%
import sklearn.svm
import PIL.Image
import numpy as np

# %%
def imageToData(filename):
    grayImage = PIL.Image.open(filename).convert("L")
    grayImage = grayImage.resize((8,8),PIL.Image.Resampling.LANCZOS)
    numImage = np.asarray(grayImage, dtype = float)
    numImage = 16 - np.floor(17 * numImage / 256)
    numImage = numImage.flatten()
    return numImage

def predictDigits(data):
    digits = sklearn.datasets.load_digits()
    clf = sklearn.svm.SVC(gamma = 0.001)
    clf.fit(digits.data, digits.target)
    n = clf.predict([data])
    print("予測=", n)

data = imageToData("/Users/kato/Desktop/mypython/python_1nensei_dai2han_sample/chapter5/2.png")
predictDigits(data)
# Out:
# 予測= [2]
