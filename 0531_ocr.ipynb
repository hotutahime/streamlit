# %%
import os
from PIL import Image
import pyocr

# %%
tools = pyocr.get_available_tools()
tool = tools[0]
print("Will use tool ‘%s' "% (tool.get_name()))
# Out:
# Will use tool ‘Tesseract (sh)'

# %%
img = Image.open("/Users/kato/Downloads/X0011.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=759x502>

# %%
txt = tool.image_to_string(img, lang="jpn", builder=pyocr.builders.TextBuilder(tesseract_layout=3))
print(txt)
# Out:
# No
#
# 日
#
# 11
#
# 納品 書 ( 控 ) _ 9403g
#
# 150
#
# 様
#
# 株 式 会 社 すす 拓 ラジ オ
#
# 法 谷 区 小谷 1ー1ー1
#
# [1
# ら
# 回
# 3
# [| | に 4
# | ミ
# 回 | 品
# 誠 | ら | らら | | 1 al sl sg
# ・「 さ | ら | さら 「 さ ssl sl s|
# 同 | ら |「 ら [らら | elsle
# [lgmlmlslmlslsla
# 計ら | に | | らき さ | | oe を を
# 4L ミ LLSlslslaslslal =
# |
# [|
# 邊 回 回 自 自 回 身 自 闘 四
# 用
# gl る |a|elslslaslslsles
# る 3 る 3| 品 る | る | | | 司 慈 |
# | 品 | 品 | 品 | 党 | 紀 | 紀 | 所
# 着 ご =| | | さ 8
# め
# 内
# に 替
# 放 回
# 3 | 志
# ヵ | lololol |
# 2| lolew| | |
# 加 | | 私 | 私 | 私 | と |
# 葵 | | ]: 記
# る | | トト | ト | 小 | や | 趣 | 刀 | 更
# 較 | と | | | 胃 | 幸 | 胃 |
# で | | | 人 | | ボ | 普 | 組 | 具
# 吾 | | も | ああ | も | 1|
# を | | 玉 ト R| ポ | 過 | 時 | 時
# に
# WW 旨 昌 せ W
#
# 2 ョ 2
