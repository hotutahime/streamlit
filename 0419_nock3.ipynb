# %%
import pandas as pd

# %%
uselog = pd.read_csv("/Users/kato/Desktop/nock/100knock-data_analytics/3章/use_log.csv")
customer = pd.read_csv("/Users/kato/Desktop/nock/100knock-data_analytics/3章/customer_master.csv")
class_master = pd.read_csv("/Users/kato/Desktop/nock/100knock-data_analytics/3章/class_master.csv")
campaign_master = pd.read_csv("/Users/kato/Desktop/nock/100knock-data_analytics/3章/campaign_master.csv")

# %%
print(len(uselog))
print(len(customer))
print(len(class_master))
print(len(campaign_master))
# Out:
# 197428
# 4192
# 3
# 3

# %%
uselog.head()
# Out:
#             log_id customer_id     usedate
# 0  L00000049012330    AS009373  2018-04-01
# 1  L00000049012331    AS015315  2018-04-01
# 2  L00000049012332    AS040841  2018-04-01
# 3  L00000049012333    AS046594  2018-04-01
# 4  L00000049012334    AS073285  2018-04-01

# %%
customer.head()
# Out:
#   customer_id   name class gender           start_date end_date campaign_id
# 0    OA832399   XXXX   C01      F  2015-05-01 00:00:00      NaN         CA1  \
# 1    PL270116  XXXXX   C01      M  2015-05-01 00:00:00      NaN         CA1
# 2    OA974876  XXXXX   C01      M  2015-05-01 00:00:00      NaN         CA1
# 3    HD024127  XXXXX   C01      F  2015-05-01 00:00:00      NaN         CA1
# 4    HD661448  XXXXX   C03      F  2015-05-01 00:00:00      NaN         CA1
#
#    is_deleted
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
class_master.head()
# Out:
#   class class_name  price
# 0   C01     オールタイム  10500
# 1   C02      デイタイム   7500
# 2   C03        ナイト   6000

# %%
campaign_master.head()
# Out:
#   campaign_id campaign_name
# 0         CA1            通常
# 1         CA2         入会費半額
# 2         CA3         入会費無料

# %%
customer_join = pd.merge(customer , class_master , on="class" , how="left")
customer_join.head()
# Out:
#   customer_id   name class gender           start_date end_date campaign_id
# 0    OA832399   XXXX   C01      F  2015-05-01 00:00:00      NaN         CA1  \
# 1    PL270116  XXXXX   C01      M  2015-05-01 00:00:00      NaN         CA1
# 2    OA974876  XXXXX   C01      M  2015-05-01 00:00:00      NaN         CA1
# 3    HD024127  XXXXX   C01      F  2015-05-01 00:00:00      NaN         CA1
# 4    HD661448  XXXXX   C03      F  2015-05-01 00:00:00      NaN         CA1
#
#    is_deleted class_name  price
# 0           0     オールタイム  10500
# 1           0     オールタイム  10500
# 2           0     オールタイム  10500
# 3           0     オールタイム  10500
# 4           0        ナイト   6000

# %%
customer_join = pd.merge(customer_join , campaign_master , on="campaign_id" , how="left")
customer_join
# Out:
#      customer_id   name class gender           start_date end_date
# 0       OA832399   XXXX   C01      F  2015-05-01 00:00:00      NaN  \
# 1       PL270116  XXXXX   C01      M  2015-05-01 00:00:00      NaN
# 2       OA974876  XXXXX   C01      M  2015-05-01 00:00:00      NaN
# 3       HD024127  XXXXX   C01      F  2015-05-01 00:00:00      NaN
# 4       HD661448  XXXXX   C03      F  2015-05-01 00:00:00      NaN
# ...          ...    ...   ...    ...                  ...      ...
# 4187    HD676663   XXXX   C01      M  2019-03-14 00:00:00      NaN
# 4188    HD246549  XXXXX   C01      F  2019-03-14 00:00:00      NaN
# 4189    GD037007  XXXXX   C03      M  2019-03-14 00:00:00      NaN
# 4190    OA953150  XXXXX   C01      M  2019-03-14 00:00:00      NaN
# 4191    IK692635  XXXXX   C02      F  2019-03-15 00:00:00      NaN
#
#      campaign_id  is_deleted class_name  price campaign_name_x campaign_name_y
# 0            CA1           0     オールタイム  10500              通常              通常
# 1            CA1           0     オールタイム  10500              通常              通常
# 2            CA1           0     オールタイム  10500              通常              通常
# 3            CA1           0     オールタイム  10500              通常              通常
# 4            CA1           0        ナイト   6000              通常              通常
# ...          ...         ...        ...    ...             ...             ...
# 4187         CA1           0     オールタイム  10500              通常              通常
# 4188         CA1           0     オールタイム  10500              通常              通常
# 4189         CA1           0        ナイト   6000              通常              通常
# 4190         CA1           0     オールタイム  10500              通常              通常
# 4191         CA1           0      デイタイム   7500              通常              通常
#
# [4192 rows x 12 columns]

# %%
print(len(customer))
print(len(customer_join))
# Out:
# 4192
# 4192

# %%
#欠損値の有無を確認
customer_join.isnull().sum()
# Out:
# customer_id           0
# name                  0
# class                 0
# gender                0
# start_date            0
# end_date           2842
# campaign_id           0
# is_deleted            0
# class_name            0
# price                 0
# campaign_name_x       0
# campaign_name_y       0
# dtype: int64

# %%
customer_join.groupby("class_name").count()["customer_id"]
# Out:
# class_name
# オールタイム    2045
# デイタイム     1019
# ナイト       1128
# Name: customer_id, dtype: int64

# %%
customer_join.groupby("campaign_id").count()["customer_id"]
# Out:
# campaign_id
# CA1    3050
# CA2     650
# CA3     492
# Name: customer_id, dtype: int64

# %%
customer_join.groupby("gender").count()["customer_id"]
# Out:
# gender
# F    1983
# M    2209
# Name: customer_id, dtype: int64

# %%
customer_join.groupby("is_deleted").count()["customer_id"]
# Out:
# is_deleted
# 0    2842
# 1    1350
# Name: customer_id, dtype: int64

# %%
customer_join["start_date"] = pd.to_datetime(customer_join["start_date"])
customer_join
# Out:
#      customer_id   name class gender start_date end_date campaign_id
# 0       OA832399   XXXX   C01      F 2015-05-01      NaN         CA1  \
# 1       PL270116  XXXXX   C01      M 2015-05-01      NaN         CA1
# 2       OA974876  XXXXX   C01      M 2015-05-01      NaN         CA1
# 3       HD024127  XXXXX   C01      F 2015-05-01      NaN         CA1
# 4       HD661448  XXXXX   C03      F 2015-05-01      NaN         CA1
# ...          ...    ...   ...    ...        ...      ...         ...
# 4187    HD676663   XXXX   C01      M 2019-03-14      NaN         CA1
# 4188    HD246549  XXXXX   C01      F 2019-03-14      NaN         CA1
# 4189    GD037007  XXXXX   C03      M 2019-03-14      NaN         CA1
# 4190    OA953150  XXXXX   C01      M 2019-03-14      NaN         CA1
# 4191    IK692635  XXXXX   C02      F 2019-03-15      NaN         CA1
#
#       is_deleted class_name  price campaign_name_x campaign_name_y
# 0              0     オールタイム  10500              通常              通常
# 1              0     オールタイム  10500              通常              通常
# 2              0     オールタイム  10500              通常              通常
# 3              0     オールタイム  10500              通常              通常
# 4              0        ナイト   6000              通常              通常
# ...          ...        ...    ...             ...             ...
# 4187           0     オールタイム  10500              通常              通常
# 4188           0     オールタイム  10500              通常              通常
# 4189           0        ナイト   6000              通常              通常
# 4190           0     オールタイム  10500              通常              通常
# 4191           0      デイタイム   7500              通常              通常
#
# [4192 rows x 12 columns]

# %%
customer_start = customer_join.loc[customer_join["start_date"]>pd.to_datetime("20180401")]
customer_start
# Out:
#      customer_id   name class gender start_date             end_date
# 2831    HI195873    XXX   C01      F 2018-04-02  2018-08-31 00:00:00  \
# 2832    TS322485     XX   C03      F 2018-04-02  2018-08-31 00:00:00
# 2833    IK552971  XXXXX   C02      F 2018-04-02  2018-08-31 00:00:00
# 2834    PL000560    XXX   C01      M 2018-04-02  2018-07-31 00:00:00
# 2835    HD218970  XXXXX   C01      F 2018-04-02  2018-11-30 00:00:00
# ...          ...    ...   ...    ...        ...                  ...
# 4187    HD676663   XXXX   C01      M 2019-03-14                  NaN
# 4188    HD246549  XXXXX   C01      F 2019-03-14                  NaN
# 4189    GD037007  XXXXX   C03      M 2019-03-14                  NaN
# 4190    OA953150  XXXXX   C01      M 2019-03-14                  NaN
# 4191    IK692635  XXXXX   C02      F 2019-03-15                  NaN
#
#      campaign_id  is_deleted class_name  price campaign_name_x
# 2831         CA3           1     オールタイム  10500           入会費無料  \
# 2832         CA3           1        ナイト   6000           入会費無料
# 2833         CA3           1      デイタイム   7500           入会費無料
# 2834         CA3           1     オールタイム  10500           入会費無料
# 2835         CA3           1     オールタイム  10500           入会費無料
# ...          ...         ...        ...    ...             ...
# 4187         CA1           0     オールタイム  10500              通常
# 4188         CA1           0     オールタイム  10500              通常
# 4189         CA1           0        ナイト   6000              通常
# 4190         CA1           0     オールタイム  10500              通常
# 4191         CA1           0      デイタイム   7500              通常
#
#      campaign_name_y customer_start
# 2831           入会費無料         201804
# 2832           入会費無料         201804
# 2833           入会費無料         201804
# 2834           入会費無料         201804
# 2835           入会費無料         201804
# ...              ...            ...
# 4187              通常         201903
# 4188              通常         201903
# 4189              通常         201903
# 4190              通常         201903
# 4191              通常         201903
#
# [1361 rows x 13 columns]
