# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/kato/Desktop/mypython/awesomebook-master/data/reserve.csv" , encoding="shift-jis" , index_col=0)

# %%
df
# Out:
#            hotel_id customer_id     reserve_datetime checkin_date
# reserve_id
# r1             h_75         c_1  2016-03-06 13:09:42   2016-03-26  \
# r2            h_219         c_1  2016-07-16 23:39:55   2016-07-20
# r3            h_179         c_1  2016-09-24 10:03:17   2016-10-19
# r4            h_214         c_1  2017-03-08 03:20:10   2017-03-29
# r5             h_16         c_1  2017-09-05 19:50:37   2017-09-22
# ...             ...         ...                  ...          ...
# r4026         h_129       c_999  2017-06-27 23:00:02   2017-07-10
# r4027          h_97       c_999  2017-09-29 05:24:57   2017-10-09
# r4028          h_27       c_999  2018-03-14 05:01:45   2018-04-02
# r4029          h_48      c_1000  2016-04-16 15:20:17   2016-05-10
# r4030         h_117      c_1000  2016-06-06 08:16:51   2016-07-06
#
#            checkin_time checkout_date  people_num  total_price
# reserve_id
# r1             10:00:00    2016-03-29           4        97200
# ...

# %%
df["customer_id"]
# Out:
# reserve_id
# r1          c_1
# r2          c_1
# r3          c_1
# r4          c_1
# r5          c_1
#           ...
# r4026     c_999
# r4027     c_999
# r4028     c_999
# r4029    c_1000
# r4030    c_1000
# Name: customer_id, Length: 4030, dtype: object

# %%
df[["customer_id" , "checkin_time"]]
# Out:
#            customer_id checkin_time
# reserve_id
# r1                 c_1     10:00:00
# r2                 c_1     11:30:00
# r3                 c_1     09:00:00
# r4                 c_1     11:00:00
# r5                 c_1     10:30:00
# ...                ...          ...
# r4026            c_999     09:30:00
# r4027            c_999     10:30:00
# r4028            c_999     11:30:00
# r4029           c_1000     09:30:00
# r4030           c_1000     09:00:00
#
# [4030 rows x 2 columns]

# %%
list = ["c_1" , "c_3" , "c_5"]

df[df["customer_id"].isin(list)]
# Out:
#            hotel_id customer_id     reserve_datetime checkin_date
# reserve_id
# r1             h_75         c_1  2016-03-06 13:09:42   2016-03-26  \
# r2            h_219         c_1  2016-07-16 23:39:55   2016-07-20
# r3            h_179         c_1  2016-09-24 10:03:17   2016-10-19
# r4            h_214         c_1  2017-03-08 03:20:10   2017-03-29
# r5             h_16         c_1  2017-09-05 19:50:37   2017-09-22
# r6            h_241         c_1  2017-11-27 18:47:05   2017-12-04
# r7            h_256         c_1  2017-12-29 10:38:36   2018-01-25
# r8            h_241         c_1  2018-05-26 08:42:51   2018-06-08
# r17           h_115         c_3  2016-05-10 12:20:32   2016-05-17
# r18           h_132         c_3  2016-10-22 02:18:48   2016-11-12
# r19            h_23         c_3  2017-01-11 22:54:09   2017-02-08
# r20           h_292         c_3  2017-02-23 07:10:30   2017-03-03
# r21           h_153         c_3  2017-04-06 18:12:10   2017-04-16
# ...

# %%
df2 = pd.pivot_table(df, values="total_price" , index="customer_id" , columns="people_num" , aggfunc=sum)
df2
# Out:
# people_num          1         2         3         4
# customer_id
# c_1          109500.0   54200.0  104100.0  291600.0
# c_10              NaN  224400.0  153000.0  200000.0
# c_100         31800.0  113600.0  105900.0       NaN
# c_1000        44100.0       NaN       NaN  540000.0
# c_101         30700.0  111600.0   87300.0   64000.0
# ...               ...       ...       ...       ...
# c_994         25200.0       NaN       NaN       NaN
# c_995         38000.0  155800.0   81300.0  322000.0
# c_996             NaN  335200.0  225900.0       NaN
# c_997             NaN  258800.0   96000.0       NaN
# c_999         37200.0  132600.0   59400.0   62400.0
#
# [888 rows x 4 columns]

# %%
df.query('"customer_id" == "c_1"')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df.query('"customer_id" == "c_1"')
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/frame.py:4452, in DataFrame.query(self, expr, inplace, **kwargs)
#    4449 res = self.eval(expr, **kwargs)
#    4451 try:
# -> 4452     result = self.loc[res]
#    4453 except ValueError:
#    4454     # when res is multi-dimensional loc raises, but this is sometimes a
#    4455     # valid query
#    4456     result = self[res]
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandas/core/indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...
