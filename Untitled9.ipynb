# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/kato/Desktop/mypython/awesomebook-master/data/reserve.csv" , encoding="utf-8" , index_col="hotel_id")

# %%
df
# Out:
#          reserve_id customer_id     reserve_datetime checkin_date
# hotel_id
# h_75             r1         c_1  2016-03-06 13:09:42   2016-03-26  \
# h_219            r2         c_1  2016-07-16 23:39:55   2016-07-20
# h_179            r3         c_1  2016-09-24 10:03:17   2016-10-19
# h_214            r4         c_1  2017-03-08 03:20:10   2017-03-29
# h_16             r5         c_1  2017-09-05 19:50:37   2017-09-22
# ...             ...         ...                  ...          ...
# h_129         r4026       c_999  2017-06-27 23:00:02   2017-07-10
# h_97          r4027       c_999  2017-09-29 05:24:57   2017-10-09
# h_27          r4028       c_999  2018-03-14 05:01:45   2018-04-02
# h_48          r4029      c_1000  2016-04-16 15:20:17   2016-05-10
# h_117         r4030      c_1000  2016-06-06 08:16:51   2016-07-06
#
#          checkin_time checkout_date  people_num  total_price
# hotel_id
# h_75         10:00:00    2016-03-29           4        97200
# ...

# %%
"dfの、値は合計金額で、行はホテルいっで、列は人数毎で、合計金額は足し算
df2 = pd.pivot_table(df, values="total_price", index="hotel_id", columns="people_num" , aggfunc=sum)

# %%
df2
# Out:
# people_num         1         2         3          4
# hotel_id
# h_1         156600.0  156600.0  391500.0   417600.0
# h_10         11200.0       NaN   50400.0    67200.0
# h_100        19200.0  105600.0  158400.0   268800.0
# h_101       182000.0  140000.0  462000.0   504000.0
# h_102        36000.0   48000.0  198000.0   144000.0
# ...              ...       ...       ...        ...
# h_95        216000.0  864000.0  259200.0  2246400.0
# h_96          7400.0  133200.0  199800.0    88800.0
# h_97        167200.0  376200.0  125400.0   668800.0
# h_98        132300.0  264600.0  793800.0   453600.0
# h_99        179200.0  448000.0       NaN  1164800.0
#
# [300 rows x 4 columns]
