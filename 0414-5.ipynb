# %%
import pandas as pd
import numpy as np

# %%
reserve_tb = pd.read_csv("/Users/kato/Desktop/mypython/awesomebook-master/data/reserve.csv" , encoding="utf-8")

# %%
reserve_tb
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date
# 0            r1     h_75         c_1  2016-03-06 13:09:42   2016-03-26  \
# 1            r2    h_219         c_1  2016-07-16 23:39:55   2016-07-20
# 2            r3    h_179         c_1  2016-09-24 10:03:17   2016-10-19
# 3            r4    h_214         c_1  2017-03-08 03:20:10   2017-03-29
# 4            r5     h_16         c_1  2017-09-05 19:50:37   2017-09-22
# ...         ...      ...         ...                  ...          ...
# 4025      r4026    h_129       c_999  2017-06-27 23:00:02   2017-07-10
# 4026      r4027     h_97       c_999  2017-09-29 05:24:57   2017-10-09
# 4027      r4028     h_27       c_999  2018-03-14 05:01:45   2018-04-02
# 4028      r4029     h_48      c_1000  2016-04-16 15:20:17   2016-05-10
# 4029      r4030    h_117      c_1000  2016-06-06 08:16:51   2016-07-06
#
#      checkin_time checkout_date  people_num  total_price
# 0        10:00:00    2016-03-29           4        97200
# ...

# %%
reserve_tb[["reserve_id" , "hotel_id"  , "customer_id" , "reserve_datetime"]]
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime
# 0            r1     h_75         c_1  2016-03-06 13:09:42
# 1            r2    h_219         c_1  2016-07-16 23:39:55
# 2            r3    h_179         c_1  2016-09-24 10:03:17
# 3            r4    h_214         c_1  2017-03-08 03:20:10
# 4            r5     h_16         c_1  2017-09-05 19:50:37
# ...         ...      ...         ...                  ...
# 4025      r4026    h_129       c_999  2017-06-27 23:00:02
# 4026      r4027     h_97       c_999  2017-09-29 05:24:57
# 4027      r4028     h_27       c_999  2018-03-14 05:01:45
# 4028      r4029     h_48      c_1000  2016-04-16 15:20:17
# 4029      r4030    h_117      c_1000  2016-06-06 08:16:51
#
# [4030 rows x 4 columns]

# %%
#axis=1は列の削除
reserve_tb.drop(["checkin_date" , "checkout_date"], axis=1)
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime checkin_time
# 0            r1     h_75         c_1  2016-03-06 13:09:42     10:00:00  \
# 1            r2    h_219         c_1  2016-07-16 23:39:55     11:30:00
# 2            r3    h_179         c_1  2016-09-24 10:03:17     09:00:00
# 3            r4    h_214         c_1  2017-03-08 03:20:10     11:00:00
# 4            r5     h_16         c_1  2017-09-05 19:50:37     10:30:00
# ...         ...      ...         ...                  ...          ...
# 4025      r4026    h_129       c_999  2017-06-27 23:00:02     09:30:00
# 4026      r4027     h_97       c_999  2017-09-29 05:24:57     10:30:00
# 4027      r4028     h_27       c_999  2018-03-14 05:01:45     11:30:00
# 4028      r4029     h_48      c_1000  2016-04-16 15:20:17     09:30:00
# 4029      r4030    h_117      c_1000  2016-06-06 08:16:51     09:00:00
#
#       people_num  total_price
# 0              4        97200
# 1              2        20600
# ...

# %%
reserve_tb[["reserve_id" , "hotel_id"  , "customer_id" , "reserve_datetime" , "checkout_date"]]
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime checkout_date
# 0            r1     h_75         c_1  2016-03-06 13:09:42    2016-03-29
# 1            r2    h_219         c_1  2016-07-16 23:39:55    2016-07-21
# 2            r3    h_179         c_1  2016-09-24 10:03:17    2016-10-22
# 3            r4    h_214         c_1  2017-03-08 03:20:10    2017-03-30
# 4            r5     h_16         c_1  2017-09-05 19:50:37    2017-09-23
# ...         ...      ...         ...                  ...           ...
# 4025      r4026    h_129       c_999  2017-06-27 23:00:02    2017-07-11
# 4026      r4027     h_97       c_999  2017-09-29 05:24:57    2017-10-10
# 4027      r4028     h_27       c_999  2018-03-14 05:01:45    2018-04-04
# 4028      r4029     h_48      c_1000  2016-04-16 15:20:17    2016-05-13
# 4029      r4030    h_117      c_1000  2016-06-06 08:16:51    2016-07-09
#
# [4030 rows x 5 columns]

# %%
reserve_tb.query('"2016-10-13" <= checkout_date <= "2016-10-14"')
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date
# 284        r285    h_121        c_67  2016-09-27 06:13:19   2016-10-12  \
# 513        r514     h_74       c_120  2016-10-06 03:12:04   2016-10-11
# 1065      r1066    h_205       c_261  2016-09-14 02:57:59   2016-10-11
# 1480      r1481    h_116       c_364  2016-09-17 17:45:39   2016-10-11
# 1546      r1547    h_149       c_377  2016-09-27 08:19:24   2016-10-10
# 1709      r1710     h_59       c_422  2016-09-19 04:17:25   2016-10-10
# 1932      r1933    h_113       c_477  2016-09-24 09:04:26   2016-10-12
# 2058      r2059      h_9       c_517  2016-09-19 15:32:35   2016-10-11
# 2115      r2116     h_77       c_527  2016-10-05 00:44:09   2016-10-11
# 2170      r2171    h_177       c_540  2016-09-28 01:21:26   2016-10-11
# 2203      r2204     h_82       c_549  2016-09-27 01:47:57   2016-10-10
# 2290      r2291    h_230       c_574  2016-10-09 04:34:14   2016-10-12
# ...

# %%
list = ["2016-10-13" , "2016-10-14"]
reserve_tb[reserve_tb["checkout_date"].isin(list)]
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date
# 284        r285    h_121        c_67  2016-09-27 06:13:19   2016-10-12  \
# 513        r514     h_74       c_120  2016-10-06 03:12:04   2016-10-11
# 1065      r1066    h_205       c_261  2016-09-14 02:57:59   2016-10-11
# 1480      r1481    h_116       c_364  2016-09-17 17:45:39   2016-10-11
# 1546      r1547    h_149       c_377  2016-09-27 08:19:24   2016-10-10
# 1709      r1710     h_59       c_422  2016-09-19 04:17:25   2016-10-10
# 1932      r1933    h_113       c_477  2016-09-24 09:04:26   2016-10-12
# 2058      r2059      h_9       c_517  2016-09-19 15:32:35   2016-10-11
# 2115      r2116     h_77       c_527  2016-10-05 00:44:09   2016-10-11
# 2170      r2171    h_177       c_540  2016-09-28 01:21:26   2016-10-11
# 2203      r2204     h_82       c_549  2016-09-27 01:47:57   2016-10-10
# 2290      r2291    h_230       c_574  2016-10-09 04:34:14   2016-10-12
# ...

# %%
reserve_tb.sample(frac=0.5)
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date
# 2167      r2168    h_126       c_539  2017-02-23 12:15:58   2017-03-03  \
# 1987      r1988     h_42       c_500  2016-03-22 08:09:39   2016-03-30
# 3232      r3233     h_56       c_813  2016-01-27 04:21:50   2016-02-01
# 602        r603    h_288       c_146  2017-06-02 02:17:09   2017-06-08
# 3653      r3654     h_52       c_909  2017-06-28 20:45:13   2017-06-29
# ...         ...      ...         ...                  ...          ...
# 2474      r2475    h_284       c_620  2016-06-27 23:52:26   2016-07-03
# 1363      r1364    h_286       c_335  2017-03-10 01:09:28   2017-03-11
# 2538      r2539      h_5       c_633  2017-01-17 03:41:34   2017-02-09
# 2847      r2848    h_199       c_718  2017-04-10 17:42:04   2017-04-18
# 3562      r3563    h_123       c_885  2016-04-28 18:53:42   2016-05-19
#
#      checkin_time checkout_date  people_num  total_price
# 2167     10:00:00    2017-03-05           2        76400
# ...

# %%
x = reserve_tb["customer_id"].unique()
x
# Out:
# array(['c_1', 'c_2', 'c_3', 'c_4', 'c_5', 'c_6', 'c_7', 'c_8', 'c_9',
#        'c_10', 'c_11', 'c_12', 'c_13', 'c_15', 'c_16', 'c_17', 'c_18',
#        'c_19', 'c_21', 'c_22', 'c_24', 'c_25', 'c_26', 'c_27', 'c_28',
#        'c_29', 'c_30', 'c_31', 'c_33', 'c_34', 'c_36', 'c_39', 'c_40',
#        'c_41', 'c_43', 'c_44', 'c_45', 'c_46', 'c_47', 'c_48', 'c_49',
#        'c_50', 'c_51', 'c_52', 'c_53', 'c_54', 'c_55', 'c_56', 'c_57',
#        'c_58', 'c_59', 'c_60', 'c_61', 'c_62', 'c_63', 'c_64', 'c_65',
#        'c_66', 'c_67', 'c_68', 'c_69', 'c_70', 'c_71', 'c_73', 'c_74',
#        'c_75', 'c_76', 'c_77', 'c_78', 'c_79', 'c_81', 'c_82', 'c_83',
#        'c_84', 'c_85', 'c_86', 'c_87', 'c_88', 'c_89', 'c_90', 'c_91',
#        'c_92', 'c_93', 'c_94', 'c_96', 'c_97', 'c_98', 'c_99', 'c_100',
#        'c_101', 'c_102', 'c_103', 'c_104', 'c_105', 'c_106', 'c_107',
#        'c_108', 'c_109', 'c_110', 'c_111', 'c_112', 'c_113', 'c_114',
# ...

# %%
target = pd.Series(reserve_tb["customer_id"].unique()).sample(frac=0.5)
target
# Out:
# 55      c_64
# 33      c_41
# 645    c_733
# 546    c_621
# 592    c_674
#        ...
# 413    c_469
# 407    c_463
# 122    c_140
# 583    c_664
# 519    c_591
# Length: 444, dtype: object

# %%
reserve_tb[reserve_tb["customer_id"].isin(target)]
# Out:
#      reserve_id hotel_id customer_id     reserve_datetime checkin_date
# 8            r9    h_217         c_2  2016-03-05 13:31:06   2016-03-25  \
# 9           r10    h_240         c_2  2016-06-25 09:12:22   2016-07-14
# 10          r11    h_183         c_2  2016-11-19 12:49:10   2016-12-08
# 11          r12    h_268         c_2  2017-05-24 10:06:21   2017-06-20
# 12          r13    h_223         c_2  2017-10-19 03:03:30   2017-10-21
# ...         ...      ...         ...                  ...          ...
# 4002      r4003    h_262       c_993  2017-08-01 23:47:40   2017-08-03
# 4003      r4004    h_201       c_993  2017-08-31 01:33:58   2017-09-13
# 4004      r4005    h_150       c_994  2016-03-25 11:51:26   2016-04-02
# 4020      r4021    h_159       c_997  2016-01-08 20:30:10   2016-01-09
# 4021      r4022    h_172       c_997  2016-05-13 09:08:55   2016-06-06
#
#      checkin_time checkout_date  people_num  total_price
# 8        09:30:00    2016-03-27           3        68400
# ...

# %%
reserve_tb.groupby("hotel_id").agg({"reserve_id":"count" , "customer_id":"nunique"})
# Out:
#           reserve_id  customer_id
# hotel_id
# h_1               10           10
# h_10               3            3
# h_100             20           19
# h_101             17           17
# h_102             13           13
# ...              ...          ...
# h_95              13           13
# h_96              13           13
# h_97              16           16
# h_98              17           16
# h_99              14           14
#
# [300 rows x 2 columns]

# %%
reserve_tb.groupby(["hotel_id" , "people_num"])["total_price"].sum().reset_index()
# Out:
#      hotel_id  people_num  total_price
# 0         h_1           1       156600
# 1         h_1           2       156600
# 2         h_1           3       391500
# 3         h_1           4       417600
# 4        h_10           1        11200
# ...       ...         ...          ...
# 1154     h_98           3       793800
# 1155     h_98           4       453600
# 1156     h_99           1       179200
# 1157     h_99           2       448000
# 1158     h_99           4      1164800
#
# [1159 rows x 3 columns]

# %%
reserve_tb.groupby(["hotel_id" , "people_num"]).agg({"total_price":sum})
# Out:
#                      total_price
# hotel_id people_num
# h_1      1                156600
#          2                156600
#          3                391500
#          4                417600
# h_10     1                 11200
# ...                          ...
# h_98     3                793800
#          4                453600
# h_99     1                179200
#          2                448000
#          4               1164800
#
# [1159 rows x 1 columns]

# %%
result = reserve_tb.groupby("hotel_id").agg({"total_price":["max","min","mean","median",lambda x: np.percentile(x, q=20)]}).reset_index()

# %%
result
# Out:
#     hotel_id total_price
#                      max    min           mean    median <lambda_0>
# 0        h_1      208800  26100  112230.000000  104400.0    73080.0
# 1       h_10       67200  11200   42933.333333   50400.0    26880.0
# 2      h_100       57600   4800   27600.000000   28800.0     9600.0
# 3      h_101      168000  14000   75764.705882   56000.0    30800.0
# 4      h_102       72000  12000   32769.230769   24000.0    18000.0
# ..       ...         ...    ...            ...       ...        ...
# 295     h_95      518400  43200  275815.384615  259200.0   146880.0
# 296     h_96       66600   7400   33015.384615   29600.0    17760.0
# 297     h_97      250800  20900   83600.000000   62700.0    20900.0
# 298     h_98      226800  18900   96723.529412   75600.0    56700.0
# 299     h_99      268800  44800  128000.000000   89600.0    67200.0
#
# [300 rows x 6 columns]

# %%
result.columns = ["hotel_id" , "price_max" , "price_min" , "price_mean" , "price_median" , "price_20per"]
result
# Out:
#     hotel_id  price_max  price_min     price_mean  price_median  price_20per
# 0        h_1     208800      26100  112230.000000      104400.0      73080.0
# 1       h_10      67200      11200   42933.333333       50400.0      26880.0
# 2      h_100      57600       4800   27600.000000       28800.0       9600.0
# 3      h_101     168000      14000   75764.705882       56000.0      30800.0
# 4      h_102      72000      12000   32769.230769       24000.0      18000.0
# ..       ...        ...        ...            ...           ...          ...
# 295     h_95     518400      43200  275815.384615      259200.0     146880.0
# 296     h_96      66600       7400   33015.384615       29600.0      17760.0
# 297     h_97     250800      20900   83600.000000       62700.0      20900.0
# 298     h_98     226800      18900   96723.529412       75600.0      56700.0
# 299     h_99     268800      44800  128000.000000       89600.0      67200.0
#
# [300 rows x 6 columns]

# %%
result2 = reserve_tb.groupby("hotel_id").agg({"total_price":["var" , "std"]}).reset_index()
result2.columns = ["hotel_id" , "price_var" , "price_std"]
result2.fillna(0, inplace=True)
result2
# Out:
#     hotel_id     price_var      price_std
# 0        h_1  3.186549e+09   56449.526127
# 1       h_10  8.258133e+08   28736.968061
# 2      h_100  3.198316e+08   17883.835689
# 3      h_101  2.402441e+09   49014.703676
# 4      h_102  3.576923e+08   18912.755159
# ..       ...           ...            ...
# 295     h_95  3.313772e+10  182037.696857
# 296     h_96  3.159231e+08   17774.225072
# 297     h_97  5.474685e+09   73991.116584
# 298     h_98  3.432893e+09   58590.896578
# 299     h_99  5.745428e+09   75798.599541
#
# [300 rows x 3 columns]

# %%
reserve_tb["total_price"].round(-3).mode()
# Out:
# 0    10000
# 1    20000
# 2    40000
# Name: total_price, dtype: int64

# %%
reserve_tb["reserve_datetime"] = pd.to_datetime(
    reserve_tb["reserve_datetime"], format="%Y-%m-%d %H:%M:%S")
reserve_tb["log_no"] = reserve_tb.groupby("customer_id")["reserve_datetime"].rank(ascending=True, method="first")

# %%
reserve_tb
# Out:
#      reserve_id hotel_id customer_id    reserve_datetime checkin_date
# 0            r1     h_75         c_1 2016-03-06 13:09:42   2016-03-26  \
# 1            r2    h_219         c_1 2016-07-16 23:39:55   2016-07-20
# 2            r3    h_179         c_1 2016-09-24 10:03:17   2016-10-19
# 3            r4    h_214         c_1 2017-03-08 03:20:10   2017-03-29
# 4            r5     h_16         c_1 2017-09-05 19:50:37   2017-09-22
# ...         ...      ...         ...                 ...          ...
# 4025      r4026    h_129       c_999 2017-06-27 23:00:02   2017-07-10
# 4026      r4027     h_97       c_999 2017-09-29 05:24:57   2017-10-09
# 4027      r4028     h_27       c_999 2018-03-14 05:01:45   2018-04-02
# 4028      r4029     h_48      c_1000 2016-04-16 15:20:17   2016-05-10
# 4029      r4030    h_117      c_1000 2016-06-06 08:16:51   2016-07-06
#
#      checkin_time checkout_date  people_num  total_price  log_no
# ...

# %%
hotel_tb = pd.read_csv("/Users/kato/Desktop/mypython/awesomebook-master/data/hotel.csv" , encoding="utf-8")

# %%
pd.merge(reserve_tb, hotel_tb, on="hotel_id" , how="inner").query("people_num == 1 & is_business")
# Out:
#      reserve_id hotel_id customer_id    reserve_datetime checkin_date
# 14         r310    h_219        c_73 2017-03-30 01:52:36   2017-04-18  \
# 18        r1433    h_219       c_348 2017-04-08 03:19:47   2017-04-25
# 21        r2992    h_219       c_756 2016-02-17 14:02:23   2016-03-01
# 24        r3522    h_219       c_875 2016-09-09 07:10:21   2016-09-20
# 101          r7    h_256         c_1 2017-12-29 10:38:36   2018-01-25
# ...         ...      ...         ...                 ...          ...
# 4019      r1637    h_281       c_401 2018-02-07 01:21:25   2018-03-06
# 4022      r2620    h_281       c_653 2016-12-03 16:56:16   2016-12-08
# 4026      r3441    h_281       c_858 2018-01-12 19:58:51   2018-01-22
# 4027      r3465    h_281       c_863 2018-07-12 04:18:50   2018-08-04
# 4028      r3787    h_281       c_942 2016-07-31 13:33:15   2016-08-27
#
#      checkin_time checkout_date  people_num  total_price  log_no  base_price
# ...

# %%
pd.merge(reserve_tb.query("people_num == 1"),
         hotel_tb.query("is_business"),
         on="hotel_id" , how="inner")
# Out:
#     reserve_id hotel_id customer_id    reserve_datetime checkin_date
# 0           r7    h_256         c_1 2017-12-29 10:38:36   2018-01-25  \
# 1         r997    h_256       c_244 2016-10-15 22:47:40   2016-10-31
# 2        r2602    h_256       c_650 2016-05-10 00:42:56   2016-05-12
# 3        r3738    h_256       c_930 2017-04-12 09:53:00   2017-05-08
# 4          r11    h_183         c_2 2016-11-19 12:49:10   2016-12-08
# ..         ...      ...         ...                 ...          ...
# 441      r2766     h_56       c_698 2017-04-08 16:41:45   2017-05-03
# 442      r2983     h_56       c_753 2016-06-18 23:17:50   2016-07-13
# 443      r2839    h_231       c_715 2016-04-06 02:51:01   2016-04-08
# 444      r3476     h_43       c_866 2016-09-17 21:09:02   2016-10-03
# 445      r3539    h_262       c_880 2016-11-06 08:55:35   2016-11-11
#
#     checkin_time checkout_date  people_num  total_price  log_no  base_price
# ...
